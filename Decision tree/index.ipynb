# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Loading data

# %%
df=pd.read_csv("car_evaluation.csv")
df.head(4)
# Out:
#   Buying Maintainance Door Persons Lugg_Boot Safety  Class
# 0  vhigh        vhigh    2       2     small    low  unacc
# 1  vhigh        vhigh    2       2     small    med  unacc
# 2  vhigh        vhigh    2       2     small   high  unacc
# 3  vhigh        vhigh    2       2       med    low  unacc

# %% [markdown]
# Data understanding and cleaning

# %%
df.columns
# Out:
# Index(['Buying', 'Maintainance', 'Door', 'Persons', 'Lugg_Boot', 'Safety',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Buying        1728 non-null   object
#  1   Maintainance  1728 non-null   object
#  2   Door          1728 non-null   object
#  3   Persons       1728 non-null   object
#  4   Lugg_Boot     1728 non-null   object
#  5   Safety        1728 non-null   object
#  6   Class         1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.isnull().sum()
# Out:
# Buying          0
# Maintainance    0
# Door            0
# Persons         0
# Lugg_Boot       0
# Safety          0
# Class           0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Buying          0
# Maintainance    0
# Door            0
# Persons         0
# Lugg_Boot       0
# Safety          0
# Class           0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
df['Persons'].value_counts()
# Out:
# Persons
# 2       576
# 4       576
# more    576
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Buying          object
# Maintainance    object
# Door            object
# Persons         object
# Lugg_Boot       object
# Safety          object
# Class           object
# dtype: object

# %% [markdown]
# Data Preprocessing

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %% [markdown]
# Train Test Split

# %%
X=df.drop(columns=['Class'],axis=1)
y=df['Class']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
X_train=encoder.fit_transform(X_train)
X_test=encoder.transform(X_test)

# %% [markdown]
# Model selection

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy',max_depth=3,random_state=0)

# %% [markdown]
# Predicting

# %%
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %% [markdown]
# Evaluating

# %%
model.score(X_test,y_test)
# Out:
# 0.7514450867052023

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7514450867052023

# %% [markdown]
# Compare train-set and test-set accuracy

# %%
y_pred_train=model.predict(X_train)
y_pred_train
# Out:
# array(['acc', 'unacc', 'unacc', ..., 'unacc', 'acc', 'unacc'],
#       dtype=object)

# %%
accuracy_score(y_train,y_pred_train)
# Out:
# 0.7872648335745297

# %% [markdown]
# Check for overfitting and underfitting

# %%
print("Training test score {:4f}".format(model.score(X_train,y_train)))
print('Test set score: {:4f}'.format(model.score(X_test,y_test)))
# Out:
# Training test score 0.787265
# Test set score: 0.751445
